# %% [markdown]
# <a href="https://colab.research.google.com/github/kangmg/compchem_with_colab/blob/main/ase_mopac_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# clear cell output
from IPython.display import clear_output

# %%
# install ase
# !pip -q install git+https://gitlab.com/ase/ase

# lastest version mopac installation
# !wget -q http://openmopac.net/mopac-22.1.1-linux.tar.gz -O ./mopac.tar.gz
# !tar vxzf ./mopac.tar.gz
# !rm ./mopac.tar.gz
clear_output()
# !echo "mopac successfully installed!"
# Out:
# mopac successfully installed!

# %%
# append mopac run file path
import os
os.environ['PATH'] += ':/content/mopac-22.1.1-linux/bin'

# %%
from ase import Atoms
from ase.io import read
from ase.calculators.mopac import MOPAC
from io import StringIO

h2xyz = """2

H 0.0 0.0 0.0
H 0.74 0.0 0.0"""

molecule = read(StringIO(h2xyz), format="xyz")

molecule.calc = MOPAC()

energy = molecule.get_potential_energy()

print(f'Energy : {energy} eV')
# Out:
# Energy : -1.3767413499186327 eV

# %%
from io import StringIO
import ase
from ase import Atoms
from ase.io import read
from ase.calculators.mopac import MOPAC
from ase.optimize import BFGS

aspirin = """21

C          2.45639       -0.16543        0.39727
C          0.78890        2.02854       -0.64816
C          2.74071        1.02327        0.12533
C          2.05734        2.11782       -0.40016
C         -3.59396        1.03209        0.04589
C          0.67738       -0.27507        0.15097
C          0.00274        0.84234       -0.35887
O          0.63293       -2.54526        0.93360
O         -1.76452        1.43252        1.56571
O         -1.24894       -1.68411        0.12975
C          0.05278       -1.58881        0.44958
C         -2.15199        1.12841        0.44513
O         -1.36167        0.82832       -0.65825
H         -1.47652       -2.60111        0.39232
H          2.60948       -1.11173        0.80284
H          0.15708        2.88266       -1.05823
H          3.80777        1.09126        0.32364
H          2.59044        3.04081       -0.61405
H         -3.81640        0.02049       -0.30287
H         -4.22480        1.24591        0.91440
H         -3.81296        1.76576       -0.73332"""

aspirin_mol:ase.Atoms = read(StringIO(aspirin), format="xyz")

aspirin_mol.calc = MOPAC()

print(f"\nopt : {aspirin_mol.get_potential_energy()} eV\n")

optimizer = BFGS(aspirin_mol)

optimizer.run()

print(f"\nopt : {aspirin_mol.get_potential_energy()} eV")
# Out:
# opt : -3.3411630096420017 eV
#
#       Step     Time          Energy          fmax
# BFGS:    0 21:57:40       -3.341163       12.014108
# BFGS:    1 21:57:40       -4.775605        9.340189
# BFGS:    2 21:57:40       -6.044126        4.284364
# BFGS:    3 21:57:40       -6.326410        2.160563
# BFGS:    4 21:57:40       -6.383746        1.825743
# BFGS:    5 21:57:40       -6.456635        0.686684
# BFGS:    6 21:57:40       -6.488118        0.415242
# BFGS:    7 21:57:40       -6.505185        0.502249
# BFGS:    8 21:57:41       -6.513766        0.279713
# BFGS:    9 21:57:41       -6.520790        0.331508
# BFGS:   10 21:57:41       -6.526521        0.212022
# BFGS:   11 21:57:41       -6.528518        0.203259
# BFGS:   12 21:57:41       -6.529758        0.100613
# BFGS:   13 21:57:41       -6.530990        0.083015
# BFGS:   14 21:57:41       -6.532432        0.084722
# BFGS:   15 21:57:41       -6.533255        0.072739
# BFGS:   16 21:57:41       -6.534467        0.085236
# BFGS:   17 21:57:41       -6.535855        0.115993
# BFGS:   18 21:57:41       -6.537422        0.125415
# BFGS:   19 21:57:41       -6.538759        0.099076
# BFGS:   20 21:57:41       -6.539884        0.070676
# BFGS:   21 21:57:41       -6.540887        0.069453
# BFGS:   22 21:57:41       -6.541804        0.060709
# BFGS:   23 21:57:41       -6.542582        0.059850
# BFGS:   24 21:57:41       -6.543305        0.069663
# BFGS:   25 21:57:41       -6.544112        0.078441
# BFGS:   26 21:57:41       -6.545013        0.069426
# BFGS:   27 21:57:41       -6.545834        0.063473
# BFGS:   28 21:57:41       -6.546491        0.055586
# BFGS:   29 21:57:41       -6.547154        0.065405
# BFGS:   30 21:57:41       -6.548146        0.089498
# BFGS:   31 21:57:42       -6.549719        0.109610
# BFGS:   32 21:57:42       -6.551805        0.123961
# BFGS:   33 21:57:42       -6.553926        0.133635
# BFGS:   34 21:57:42       -6.555859        0.160173
# BFGS:   35 21:57:42       -6.557849        0.166409
# BFGS:   36 21:57:42       -6.560125        0.144057
# BFGS:   37 21:57:42       -6.562586        0.119321
# BFGS:   38 21:57:42       -6.564875        0.118903
# BFGS:   39 21:57:42       -6.566848        0.109434
# BFGS:   40 21:57:42       -6.568637        0.118037
# BFGS:   41 21:57:42       -6.570423        0.100058
# BFGS:   42 21:57:42       -6.572438        0.142188
# BFGS:   43 21:57:42       -6.574958        0.154583
# BFGS:   44 21:57:42       -6.577852        0.134491
# BFGS:   45 21:57:42       -6.578883        0.354044
# BFGS:   46 21:57:42       -6.581766        0.094347
# BFGS:   47 21:57:42       -6.582998        0.066131
# BFGS:   48 21:57:42       -6.584700        0.068549
# BFGS:   49 21:57:42       -6.585686        0.073295
# BFGS:   50 21:57:42       -6.586826        0.064011
# BFGS:   51 21:57:42       -6.587527        0.062373
# BFGS:   52 21:57:42       -6.588147        0.066810
# BFGS:   53 21:57:43       -6.588854        0.064784
# BFGS:   54 21:57:43       -6.589656        0.074731
# BFGS:   55 21:57:43       -6.590343        0.065540
# BFGS:   56 21:57:43       -6.590911        0.066662
# BFGS:   57 21:57:43       -6.591441        0.067334
# BFGS:   58 21:57:43       -6.591953        0.050116
# BFGS:   59 21:57:43       -6.592373        0.045197
#
# opt : -6.59237325671677 eV

# %%
# !cat /content/mopac.out
# Out:
#  *******************************************************************************
#  **                                                                           **
#  **                              MOPAC v22.1.1                                **
#  **                                                                           **
#  *******************************************************************************
#  **          Digital Object Identifier (DOI): 10.5281/zenodo.6511958          **
#  **    Visit the DOI location for information on how to cite this program.    **
#  *******************************************************************************
#
#                               PM7 CALCULATION RESULTS
#
#  *******************************************************************************
#  *  CALCULATION DONE:                                Mon May 20 21:56:40 2024  *
#  *  PM7        - The PM7 Hamiltonian to be used
#  *  1SCF       - DO 1 SCF AND THEN STOP
#  *  T=         - A TIME OF 172800.0 SECONDS REQUESTED
#  *  DUMP=N     - RESTART FILE WRITTEN EVERY 7200.0 SECONDS REQUESTED
#  *  RELSCF     - DEFAULT SCF CRITERION MULTIPLIED BY 0.0001
#  *              (DEFAULT SCF CRITERION = 0.00010)
#  *  GRADIENTS  - ALL GRADIENTS TO BE PRINTED
#  *  DISP       - PRINT DISPERSION AND HYDROGEN BOND ENERGIES
#  *******************************************************************************
# PM7 1SCF GRADIENTS DISP RELSCF=0.0001
#  Title: ASE calculation
#
#    ATOM   CHEMICAL          X               Y               Z
#   NUMBER   SYMBOL      (ANGSTROMS)     (ANGSTROMS)     (ANGSTROMS)
#
#      1       C          2.09228646  *  -0.17459324  *   0.29478298  *
#      2       C          0.79839072  *   2.16315861  *  -0.53633758  *
#      3       C          2.82914441  *   0.95785937  *  -0.02464211  *
#      4       C          2.18229283  *   2.12818679  *  -0.43449024  *
#      5       C         -3.52715851  *   0.80922258  *  -0.05499027  *
#      6       C          0.69212326  *  -0.16854674  *   0.19262439  *
#      7       C          0.06894340  *   1.00945958  *  -0.22547370  *
#      8       O          0.51306366  *  -2.43931564  *   0.92388462  *
#      9       O         -1.83930368  *   0.99030556  *   1.69589620  *
#     10       O         -1.34301227  *  -1.37081269  *   0.35196220  *
#     11       C          0.00700470  *  -1.41639801  *   0.53332570  *
#     12       C         -2.17610655  *   0.94350370  *   0.54948277  *
#     13       O         -1.26906149  *   1.07978969  *  -0.48588889  *
#     14       H         -1.78976896  *  -2.20842853  *   0.63959574  *
#     15       H          2.59414098  *  -1.08963754  *   0.62844059  *
#     16       H          0.27019039  *   3.06217627  *  -0.84519870  *
#     17       H          3.91438904  *   0.93451111  *   0.04570400  *
#     18       H          2.76654716  *   3.01675156  *  -0.67907548  *
#     19       H         -3.66135493  *  -0.20934136  *  -0.46001061  *
#     20       H         -4.31692537  *   0.98779014  *   0.68966420  *
#     21       H         -3.68364675  *   1.50304189  *  -0.89673219  *
#
#
#
#           CARTESIAN COORDINATES
#
#     NO.       ATOM           X           Y           Z
#
#      1         C          2.0923     -0.1746      0.2948
#      2         C          0.7984      2.1632     -0.5363
#      3         C          2.8291      0.9579     -0.0246
#      4         C          2.1823      2.1282     -0.4345
#      5         C         -3.5272      0.8092     -0.0550
#      6         C          0.6921     -0.1685      0.1926
#      7         C          0.0689      1.0095     -0.2255
#      8         O          0.5131     -2.4393      0.9239
#      9         O         -1.8393      0.9903      1.6959
#     10         O         -1.3430     -1.3708      0.3520
#     11         C          0.0070     -1.4164      0.5333
#     12         C         -2.1761      0.9435      0.5495
#     13         O         -1.2691      1.0798     -0.4859
#     14         H         -1.7898     -2.2084      0.6396
#     15         H          2.5941     -1.0896      0.6284
#     16         H          0.2702      3.0622     -0.8452
#     17         H          3.9144      0.9345      0.0457
#     18         H          2.7665      3.0168     -0.6791
#     19         H         -3.6614     -0.2093     -0.4600
#     20         H         -4.3169      0.9878      0.6897
#     21         H         -3.6836      1.5030     -0.8967
#
#  General Reference for PM7:
#  "Optimization of Parameters for Semiempirical Methods VI: More Modifications to the
#  NDDO Approximations and Re-optimization of Parameters", J. J. P. Stewart, J. Mol. Mod., 1:32, 19 (2013)
#  https://link.springer.com/article/10.1007/s00894-012-1667-x
#
#            Empirical Formula: C9 H8 O4  =    21 atoms
#
#
#
#       MOLECULAR POINT GROUP   :   C1
#
#
#       RHF CALCULATION, NO. OF DOUBLY OCCUPIED LEVELS = 34
#
#   SCF CRITERION =    0.1000E-07
#
#  -------------------------------------------------------------------------------
#  PM7 1SCF GRADIENTS DISP RELSCF=0.0001
#  Title: ASE calculation
#
#
#
#      1SCF WAS SPECIFIED, SO BFGS WAS NOT USED
#      SCF FIELD WAS ACHIEVED
#
#
#                               PM7 CALCULATION
#                                                        MOPAC v22.1.1 Linux
#                                                        Mon May 20 21:56:40 2024
#
#
#
#
#           FINAL HEAT OF FORMATION =       -152.02374 KCAL/MOL =    -636.06733 KJ/MOL
#
#           TOTAL ENERGY            =     -55231.00471 KCAL/MOL = ELECTRONIC ENERGY + CORE-CORE REPULSION
#           ENERGY OF ATOMS         =      55082.48497 KCAL/MOL
#                               SUM =       -148.51974 KCAL/MOL
#           DISPERSION ENERGY       =         -3.50400 KCAL/MOL
#                               SUM =       -152.02374 KCAL/MOL = FINAL HEAT OF FORMATION
#
#
#
#           TOTAL ENERGY            =      -2395.04305 EV
#           ELECTRONIC ENERGY       =     -12522.07641 EV
#           CORE-CORE REPULSION     =      10127.03336 EV
#           COSMO AREA              =        195.54 SQUARE ANGSTROMS
#           COSMO VOLUME            =        200.90 CUBIC ANGSTROMS
#
#           GRADIENT NORM           =          2.67908          =       0.58462 PER ATOM
#           IONIZATION POTENTIAL    =          9.904287 EV
#           HOMO LUMO ENERGIES (EV) =         -9.904 -0.817
#           NO. OF FILLED LEVELS    =         34
#           MOLECULAR WEIGHT        =        180.1598         POINT GROUP:  C1
#
#           MOLECULAR DIMENSIONS (Angstroms)
#
#             Atom       Atom       Distance
#             H    20    H    17     8.25664
#             H    16    O     8     5.78235
#             O     9    H    19     2.55295
#
#
#           SCF CALCULATIONS        =          1
#
#           WALL-CLOCK TIME         =      0.031 SECONDS
#           COMPUTATION TIME        =      0.026 SECONDS
#
#           LARGEST ATOMIC GRADIENTS
#
#           Atom     Label                     Cartesian Gradients           Cartesian Coordinates       |Gradient|
#                                            X          Y          Z        X          Y          Z
#
#              4       C                   0.130      0.316      0.985    2.18229    2.12819   -0.43449      1.042
#              2       C                   0.032     -0.404     -0.842    0.79839    2.16316   -0.53634      0.934
#             17       H                  -0.485     -0.422     -0.283    3.91439    0.93451    0.04570      0.702
#             16       H                  -0.326     -0.172      0.543    0.27019    3.06218   -0.84520      0.656
#             20       H                   0.026     -0.188     -0.610   -4.31693    0.98779    0.68966      0.639
#             21       H                  -0.520     -0.174     -0.263   -3.68365    1.50304   -0.89673      0.608
#             14       H                  -0.081     -0.446      0.402   -1.78977   -2.20843    0.63960      0.606
#             10       O                   0.319     -0.504     -0.047   -1.34301   -1.37081    0.35196      0.598
#             15       H                  -0.588      0.037      0.063    2.59414   -1.08964    0.62844      0.592
#              3       C                  -0.245      0.014     -0.504    2.82914    0.95786   -0.02464      0.561
#
#
#
#        FINAL  POINT  AND  DERIVATIVES
#
#    PARAMETER     ATOM    TYPE            VALUE        GRADIENT
#       1          1  C    CARTESIAN X     2.092286      0.183131  KCAL/ANGSTROM
#       2          1  C    CARTESIAN Y    -0.174593      0.024007  KCAL/ANGSTROM
#       3          1  C    CARTESIAN Z     0.294783      0.257682  KCAL/ANGSTROM
#       4          2  C    CARTESIAN X     0.798391      0.032155  KCAL/ANGSTROM
#       5          2  C    CARTESIAN Y     2.163159     -0.403673  KCAL/ANGSTROM
#       6          2  C    CARTESIAN Z    -0.536338     -0.841589  KCAL/ANGSTROM
#       7          3  C    CARTESIAN X     2.829144     -0.245484  KCAL/ANGSTROM
#       8          3  C    CARTESIAN Y     0.957859      0.013911  KCAL/ANGSTROM
#       9          3  C    CARTESIAN Z    -0.024642     -0.504049  KCAL/ANGSTROM
#      10          4  C    CARTESIAN X     2.182293      0.129518  KCAL/ANGSTROM
#      11          4  C    CARTESIAN Y     2.128187      0.315549  KCAL/ANGSTROM
#      12          4  C    CARTESIAN Z    -0.434490      0.984876  KCAL/ANGSTROM
#      13          5  C    CARTESIAN X    -3.527159      0.363381  KCAL/ANGSTROM
#      14          5  C    CARTESIAN Y     0.809223      0.303232  KCAL/ANGSTROM
#      15          5  C    CARTESIAN Z    -0.054990     -0.061923  KCAL/ANGSTROM
#      16          6  C    CARTESIAN X     0.692123      0.155646  KCAL/ANGSTROM
#      17          6  C    CARTESIAN Y    -0.168547      0.023124  KCAL/ANGSTROM
#      18          6  C    CARTESIAN Z     0.192624     -0.153019  KCAL/ANGSTROM
#      19          7  C    CARTESIAN X     0.068943      0.186492  KCAL/ANGSTROM
#      20          7  C    CARTESIAN Y     1.009460     -0.004334  KCAL/ANGSTROM
#      21          7  C    CARTESIAN Z    -0.225474      0.520948  KCAL/ANGSTROM
#      22          8  O    CARTESIAN X     0.513064     -0.066091  KCAL/ANGSTROM
#      23          8  O    CARTESIAN Y    -2.439316     -0.102148  KCAL/ANGSTROM
#      24          8  O    CARTESIAN Z     0.923885     -0.485264  KCAL/ANGSTROM
#      25          9  O    CARTESIAN X    -1.839304      0.104403  KCAL/ANGSTROM
#      26          9  O    CARTESIAN Y     0.990306      0.189117  KCAL/ANGSTROM
#      27          9  O    CARTESIAN Z     1.695896      0.312101  KCAL/ANGSTROM
#      28         10  O    CARTESIAN X    -1.343012      0.319488  KCAL/ANGSTROM
#      29         10  O    CARTESIAN Y    -1.370813     -0.503597  KCAL/ANGSTROM
#      30         10  O    CARTESIAN Z     0.351962     -0.046510  KCAL/ANGSTROM
#      31         11  C    CARTESIAN X     0.007005      0.247113  KCAL/ANGSTROM
#      32         11  C    CARTESIAN Y    -1.416398      0.143309  KCAL/ANGSTROM
#      33         11  C    CARTESIAN Z     0.533326      0.346112  KCAL/ANGSTROM
#      34         12  C    CARTESIAN X    -2.176107      0.164024  KCAL/ANGSTROM
#      35         12  C    CARTESIAN Y     0.943504      0.250007  KCAL/ANGSTROM
#      36         12  C    CARTESIAN Z     0.549483      0.014346  KCAL/ANGSTROM
#      37         13  O    CARTESIAN X    -1.269061      0.339936  KCAL/ANGSTROM
#      38         13  O    CARTESIAN Y     1.079790      0.396757  KCAL/ANGSTROM
#      39         13  O    CARTESIAN Z    -0.485889      0.122323  KCAL/ANGSTROM
#      40         14  H    CARTESIAN X    -1.789769     -0.081204  KCAL/ANGSTROM
#      41         14  H    CARTESIAN Y    -2.208429     -0.445800  KCAL/ANGSTROM
#      42         14  H    CARTESIAN Z     0.639596      0.402394  KCAL/ANGSTROM
#      43         15  H    CARTESIAN X     2.594141     -0.587963  KCAL/ANGSTROM
#      44         15  H    CARTESIAN Y    -1.089638      0.037284  KCAL/ANGSTROM
#      45         15  H    CARTESIAN Z     0.628441      0.062597  KCAL/ANGSTROM
#      46         16  H    CARTESIAN X     0.270190     -0.326060  KCAL/ANGSTROM
#      47         16  H    CARTESIAN Y     3.062176     -0.171594  KCAL/ANGSTROM
#      48         16  H    CARTESIAN Z    -0.845199      0.542597  KCAL/ANGSTROM
#      49         17  H    CARTESIAN X     3.914389     -0.484538  KCAL/ANGSTROM
#      50         17  H    CARTESIAN Y     0.934511     -0.421743  KCAL/ANGSTROM
#      51         17  H    CARTESIAN Z     0.045704     -0.283196  KCAL/ANGSTROM
#      52         18  H    CARTESIAN X     2.766547     -0.126594  KCAL/ANGSTROM
#      53         18  H    CARTESIAN Y     3.016752      0.297885  KCAL/ANGSTROM
#      54         18  H    CARTESIAN Z    -0.679075     -0.386789  KCAL/ANGSTROM
#      55         19  H    CARTESIAN X    -3.661355      0.187357  KCAL/ANGSTROM
#      56         19  H    CARTESIAN Y    -0.209341      0.420748  KCAL/ANGSTROM
#      57         19  H    CARTESIAN Z    -0.460011      0.069044  KCAL/ANGSTROM
#      58         20  H    CARTESIAN X    -4.316925      0.025632  KCAL/ANGSTROM
#      59         20  H    CARTESIAN Y     0.987790     -0.188153  KCAL/ANGSTROM
#      60         20  H    CARTESIAN Z     0.689664     -0.609746  KCAL/ANGSTROM
#      61         21  H    CARTESIAN X    -3.683647     -0.520339  KCAL/ANGSTROM
#      62         21  H    CARTESIAN Y     1.503042     -0.173891  KCAL/ANGSTROM
#      63         21  H    CARTESIAN Z    -0.896732     -0.262937  KCAL/ANGSTROM
#
#
#
#
#    ATOM   CHEMICAL          X               Y               Z
#   NUMBER   SYMBOL      (ANGSTROMS)     (ANGSTROMS)     (ANGSTROMS)
#
#      1       C          2.09228646  *  -0.17459324  *   0.29478298  *
#      2       C          0.79839072  *   2.16315861  *  -0.53633758  *
#      3       C          2.82914441  *   0.95785937  *  -0.02464211  *
#      4       C          2.18229283  *   2.12818679  *  -0.43449024  *
#      5       C         -3.52715851  *   0.80922258  *  -0.05499027  *
#      6       C          0.69212326  *  -0.16854674  *   0.19262439  *
#      7       C          0.06894340  *   1.00945958  *  -0.22547370  *
#      8       O          0.51306366  *  -2.43931564  *   0.92388462  *
#      9       O         -1.83930368  *   0.99030556  *   1.69589620  *
#     10       O         -1.34301227  *  -1.37081269  *   0.35196220  *
#     11       C          0.00700470  *  -1.41639801  *   0.53332570  *
#     12       C         -2.17610655  *   0.94350370  *   0.54948277  *
#     13       O         -1.26906149  *   1.07978969  *  -0.48588889  *
#     14       H         -1.78976896  *  -2.20842853  *   0.63959574  *
#     15       H          2.59414098  *  -1.08963754  *   0.62844059  *
#     16       H          0.27019039  *   3.06217627  *  -0.84519870  *
#     17       H          3.91438904  *   0.93451111  *   0.04570400  *
#     18       H          2.76654716  *   3.01675156  *  -0.67907548  *
#     19       H         -3.66135493  *  -0.20934136  *  -0.46001061  *
#     20       H         -4.31692537  *   0.98779014  *   0.68966420  *
#     21       H         -3.68364675  *   1.50304189  *  -0.89673219  *
#
#                              CARTESIAN COORDINATES
#
#    1    C        2.092286457    -0.174593238     0.294782981
#    2    C        0.798390724     2.163158608    -0.536337582
#    3    C        2.829144406     0.957859373    -0.024642111
#    4    C        2.182292831     2.128186793    -0.434490241
#    5    C       -3.527158515     0.809222578    -0.054990268
#    6    C        0.692123258    -0.168546740     0.192624392
#    7    C        0.068943405     1.009459577    -0.225473705
#    8    O        0.513063664    -2.439315640     0.923884624
#    9    O       -1.839303678     0.990305563     1.695896197
#   10    O       -1.343012272    -1.370812694     0.351962197
#   11    C        0.007004701    -1.416398008     0.533325700
#   12    C       -2.176106547     0.943503703     0.549482767
#   13    O       -1.269061493     1.079789686    -0.485888886
#   14    H       -1.789768962    -2.208428533     0.639595743
#   15    H        2.594140977    -1.089637543     0.628440593
#   16    H        0.270190393     3.062176267    -0.845198696
#   17    H        3.914389038     0.934511107     0.045704002
#   18    H        2.766547162     3.016751556    -0.679075476
#   19    H       -3.661354929    -0.209341359    -0.460010609
#   20    H       -4.316925367     0.987790136     0.689664199
#   21    H       -3.683646750     1.503041887    -0.896732191
#
#
#            Empirical Formula: C9 H8 O4  =    21 atoms
#
#
#
#       MOLECULAR POINT GROUP   :   C1
#
#
#                   EIGENVALUES
#  -31.84243 -31.58497 -31.11241 -30.38851 -29.79560 -27.43085 -26.98611 -25.76231
#  -23.33229 -21.79976 -21.01510 -19.99333 -18.27307 -17.56087 -17.12890 -16.58206
#  -16.38149 -16.02886 -15.55659 -15.40846 -15.05114 -14.36179 -14.12562 -13.84302
#  -13.64153 -13.40594 -12.92925 -12.69777 -12.14385 -11.84223 -11.34907 -11.14917
#  -10.47351  -9.90429  -0.81746  -0.24046   0.90661   1.16981   1.33393   2.00953
#    2.17743   3.07395   3.24354   3.80007   3.98719   4.15802   4.41061   4.47272
#    4.67140   4.70918   4.77564   4.87293   5.21215   5.30001   5.43390   5.51973
#    5.64780   5.82862   5.88206   6.08408
#
#
#               NET ATOMIC CHARGES AND DIPOLE CONTRIBUTIONS
#
#   ATOM NO.   TYPE          CHARGE      No. of ELECS.   s-Pop       p-Pop
#     1          C          -0.032716        4.0327     1.09315     2.93957
#     2          C          -0.252422        4.2524     1.08201     3.17042
#     3          C          -0.217683        4.2177     1.07863     3.13905
#     4          C          -0.052116        4.0521     1.08975     2.96237
#     5          C          -0.502079        4.5021     1.05946     3.44261
#     6          C          -0.237080        4.2371     1.06255     3.17453
#     7          C           0.338739        3.6613     1.07918     2.58208
#     8          O          -0.504039        6.5040     1.87842     4.62562
#     9          O          -0.464722        6.4647     1.87442     4.59030
#    10          O          -0.568762        6.5688     1.84018     4.72859
#    11          C           0.668814        3.3312     1.09912     2.23207
#    12          C           0.662170        3.3378     1.11686     2.22097
#    13          O          -0.436106        6.4361     1.85176     4.58434
#    14          H           0.359375        0.6406     0.64062
#    15          H           0.178281        0.8217     0.82172
#    16          H           0.176530        0.8235     0.82347
#    17          H           0.163030        0.8370     0.83697
#    18          H           0.154096        0.8459     0.84590
#    19          H           0.194469        0.8055     0.80553
#    20          H           0.184778        0.8152     0.81522
#    21          H           0.187446        0.8126     0.81255
#  DIPOLE           X         Y         Z       TOTAL
#  POINT-CHG.    -0.773     2.233    -2.386     3.358
#  HYBRID        -0.522    -0.484     0.168     0.732
#  SUM           -1.295     1.749    -2.219     3.108
#
#
#           ATOMIC ORBITAL ELECTRON POPULATIONS
#
#      Atom    s        px        py        pz
#     1  C   1.09315   0.97405   1.05180   0.91372
#     2  C   1.08201   1.01400   1.06558   1.09084
#     3  C   1.07863   1.09023   0.99157   1.05725
#     4  C   1.08975   0.99988   1.04073   0.92176
#     5  C   1.05946   1.05120   1.21009   1.18132
#     6  C   1.06255   1.01146   0.99936   1.16371
#     7  C   1.07918   0.77401   0.93674   0.87134
#     8  O   1.87842   1.74006   1.39604   1.48952
#     9  O   1.87442   1.79288   1.50228   1.29514
#    10  O   1.84018   1.37075   1.54024   1.81760
#    11  C   1.09912   0.73281   0.82508   0.67418
#    12  C   1.11686   0.81179   0.64497   0.76420
#    13  O   1.85176   1.25154   1.84926   1.48355
#    14  H   0.64062
#    15  H   0.82172
#    16  H   0.82347
#    17  H   0.83697
#    18  H   0.84590
#    19  H   0.80553
#    20  H   0.81522
#    21  H   0.81255
#
#  **********************
#  *                    *
#  * JOB ENDED NORMALLY *
#  *                    *
#  **********************
#
#
#
#  TOTAL JOB TIME:             0.04 SECONDS
#
#  == MOPAC DONE ==

# %%
'''
    To be implemented
'''
"""
# http://openmopac.net/manual/index.html


# utils
from io import StringIO
from IPython.display import clear_output

# ase / xtb
import ase
from ase.io import read
from ase.calculators.mopac import MOPAC
from ase.optimize import BFGS

def mopac_optimize(mol:str|ase.Atoms, charge:int, method:str="PM7", spinpol:bool|None=None, uhf:int=0, clear_log=False):
  """
  Description
  -----------
  xtb geometry optimize 함수

  Parameters
  ----------
  mol (xyz format string | ase.Atoms) :
  charge (int) :
  method (str) :
  spinpol ( bool | None ) :
  uhf (int) :
  tmp_dir (str) :

  Returns
  -------
  optimized xyz (str) :
  """

  methods = ['AM1', 'MNDO', 'MNDOD', 'PM3', 'PM6', 'PM6-D3', 'PM6-DH+',
               'PM6-DH2', 'PM6-DH2X', 'PM6-D3H4', 'PM6-D3H4X', 'PMEP', 'PM7',
               'PM7-TS', 'RM1']

  # convert xyz format --> ase.Atoms
  if type(mol) == str:
    try:
      mol = ase.io.read(StringIO(mol), format="xyz")
    except:
      raise ValueError("Invalid xyz format string")

  # set XTB calculator
  mol.calc = MOPAC(method=method, charge=charge, spinpol=spinpol, uhf=uhf)
  # geometry optimize
  optimizer = BFGS(mol)
  optimizer.run()

  # get xyz format string
  with StringIO() as output:
    ase.io.write(output, mol, format="xyz")
    opt_xyz = output.getvalue()

  # clear cell output
  if clear_log:
    clear_output()

  return opt_xyz
"""
